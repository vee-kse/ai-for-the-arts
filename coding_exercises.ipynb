# %% [markdown]
# # AI for the Arts and Humanities (A): Coding Exercises
#
# This notebook collects my weekly lab work for AI for the Arts and Humanities (A). Each exercise follows the same pattern: the prompt I gave Microsoft Copilot, the code it produced, whether the code ran, and what I learned.
#
# **Goals for this notebook**
# - Be able to read code well enough to explain it to someone who has never coded before
#
# **How to read it**
# - Markdown cells hold the writing
# - Code cells hold Copilot's code
